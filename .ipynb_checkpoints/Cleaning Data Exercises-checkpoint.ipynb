# %% [markdown]
# # Cleaning Data Exercises
#
# For the exercises, you will be cleaning data in your chosen data set. [Towards Data Science](https://towardsdatascience.com/data-cleaning-in-python-the-ultimate-guide-2020-c63b88bf0a0d) outlines the steps we should take to clean data using a different data set from Kaggle. While you should use this article as a reference, make sure not to copy paste as the two data sets are very different!
#
# To start cleaning data, we first need to create a dataframe from the CSV and print out any relevant info to make sure our dataframe is ready to go.

# %%
# Import pandas and any other libraries you need here. HINT: Check out the article to see what they imported to get started!
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#import missingno as msno
#msno.matrix(df.iloc[:, :30])

# %%
# Create a new dataframe from your CSV
df = pd.read_csv("Rat_Sightings.csv")

# %%
# Print out any information you need to understand your datafr
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101914 entries, 0 to 101913
# Data columns (total 52 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      101914 non-null  int64
#  1   Created Date                    101914 non-null  object
#  2   Closed Date                     90983 non-null   object
#  3   Agency                          101914 non-null  object
#  4   Agency Name                     101914 non-null  object
#  5   Complaint Type                  101914 non-null  object
#  6   Descriptor                      101914 non-null  object
#  7   Location Type                   101908 non-null  object
#  8   Incident Zip                    101578 non-null  float64
#  9   Incident Address                92840 non-null   object
#  10  Street Name                     92839 non-null   object
#  11  Cross Street 1                  85257 non-null   object
# ...

# %%
df.describe()
# Out:
#          Unique Key   Incident Zip  Facility Type  X Coordinate (State Plane)  \
# count  1.019140e+05  101578.000000            0.0                1.012080e+05
# mean   2.815864e+07   10728.680895            NaN                1.002473e+06
# std    6.015376e+06     631.206648            NaN                1.958043e+04
# min    1.146439e+07      83.000000            NaN                9.134950e+05
# 25%    2.341452e+07   10086.250000            NaN                9.936100e+05
# 50%    2.883680e+07   10472.000000            NaN                1.001398e+06
# 75%    3.346014e+07   11222.000000            NaN                1.011951e+06
# max    3.719700e+07  100354.000000            NaN                1.066922e+06
#
#        Y Coordinate (State Plane)  School or Citywide Complaint  Vehicle Type  \
# count               101208.000000                           0.0           0.0
# mean                208639.988953                           NaN           NaN
# ...

# %%
df.head(25)
# Out:
#     Unique Key            Created Date             Closed Date Agency  \
# 0     31464015  09/04/2015 12:00:00 AM  09/18/2015 12:00:00 AM  DOHMH
# 1     31464024  09/04/2015 12:00:00 AM  10/28/2015 12:00:00 AM  DOHMH
# 2     31464025  09/04/2015 12:00:00 AM                     NaN  DOHMH
# 3     31464026  09/04/2015 12:00:00 AM  09/14/2015 12:00:00 AM  DOHMH
# 4     31464027  09/04/2015 12:00:00 AM  09/22/2015 12:00:00 AM  DOHMH
# 5     31464188  09/04/2015 12:00:00 AM  09/22/2015 12:00:00 AM  DOHMH
# 6     31464195  09/04/2015 12:00:00 AM  09/22/2015 04:26:36 PM  DOHMH
# 7     31464199  09/04/2015 12:00:00 AM                     NaN  DOHMH
# 8     31464220  09/04/2015 12:00:00 AM  08/19/2015 12:00:00 AM  DOHMH
# 9     31464802  09/04/2015 12:00:00 AM  09/25/2015 12:00:00 AM  DOHMH
# 10    31464803  09/04/2015 12:00:00 AM  07/30/2015 12:00:00 AM  DOHMH
# 11    31464858  09/04/2015 12:00:00 AM  09/15/2015 04:03:54 PM  DOHMH
# ...

# %% [markdown]
# Now you have a dataframe set up, you are ready to dive in and start cleaning!

# %% [markdown]
# ## Missing Data
#
# In the Towards Data Science article, they list 3 techniques for detecting any missing data frame. Try all three before deciding on a way to solve any missing data issues.

# %%
cols = df.columns[:51] #first 30 columns
colours = ['#000099','#ffff00' ]# yellow is missing. blue is not missing
df[cols].isna()
# Out:
#         Unique Key  Created Date  Closed Date  Agency  Agency Name  \
# 0            False         False        False   False        False
# 1            False         False        False   False        False
# 2            False         False         True   False        False
# 3            False         False        False   False        False
# 4            False         False        False   False        False
# ...            ...           ...          ...     ...          ...
# 101909       False         False        False   False        False
# 101910       False         False        False   False        False
# 101911       False         False        False   False        False
# 101912       False         False        False   False        False
# 101913       False         False         True   False        False
#
#         Complaint Type  Descriptor  Location Type  Incident Zip  \
# 0                False       False          False         False
# ...

# %%
# Plot a heatmap of any missing data

cols = df.columns[:51] #first 30 columns
colours = ['#000099','#ffff00' ]# yellow is missing. blue is not missing
sns.heatmap(df[cols].isna(), cmap =sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %%
# Try out a missing data percentage list! 
#% of missing
for col in df.columns:
    pct_missing =np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Unique Key - 0%
# Created Date - 0%
# Closed Date - 11%
# Agency - 0%
# Agency Name - 0%
# Complaint Type - 0%
# Descriptor - 0%
# Location Type - 0%
# Incident Zip - 0%
# Incident Address - 9%
# Street Name - 9%
# Cross Street 1 - 16%
# Cross Street 2 - 16%
# Intersection Street 1 - 91%
# Intersection Street 2 - 91%
# Address Type - 0%
# City - 0%
# Landmark - 100%
# Facility Type - 100%
# Status - 0%
# Due Date - 0%
# Resolution Action Updated Date - 0%
# Community Board - 0%
# Borough - 0%
# X Coordinate (State Plane) - 1%
# Y Coordinate (State Plane) - 1%
# Park Facility Name - 0%
# Park Borough - 0%
# School Name - 0%
# School Number - 0%
# School Region - 0%
# School Code - 0%
# School Phone Number - 0%
# School Address - 0%
# School City - 0%
# School State - 0%
# School Zip - 0%
# School Not Found - 1%
# School or Citywide Complaint - 100%
# Vehicle Type - 100%
# Taxi Company Borough - 100%
# Taxi Pick Up Location - 100%
# Bridge Highway Name - 100%
# ...

# %%
#pcnt_null = df.isnull().sum/len(df)
#more_than_ninety = pcnt_null[pcnt_null > 0.90].index
#df.drop(more_than_ninety, axis =1, inplace = True)

# %%
# Try out a missing data percentage list!> 90%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    if pct_missing > 0.9:
        print('{} is > {}%'.format(col, round(pct_missing*100)))
# Out:
# Intersection Street 1 is > 91%
# Intersection Street 2 is > 91%
# Landmark is > 100%
# Facility Type is > 100%
# School or Citywide Complaint is > 100%
# Vehicle Type is > 100%
# Taxi Company Borough is > 100%
# Taxi Pick Up Location is > 100%
# Bridge Highway Name is > 100%
# Bridge Highway Direction is > 100%
# Road Ramp is > 100%
# Bridge Highway Segment is > 100%
# Garage Lot Name is > 100%
# Ferry Direction is > 100%
# Ferry Terminal Name is > 100%

# %%
# Plot a missing data histogram.1ist determine # of missing
for col in df.columns:
    missing = df[col].isnull()
    num_missing = np.sum(missing)
    
    if num_missing > 0:
        print('created missing indicator for : {}'.format(col))
        df['{}_ismissing'.format(col)] = missing
#then based on the indicator, plot the histogram of missing values
ismissing_cols = [col for col in df.columns if 'ismissing' in col]
df['num_missing'] = df[ismissing_cols].sum(axis =1)

df['num_missing'].value_counts().reset_index().sort_values(by='index').plot.bar(x='index', y='num_missing')
df.num_missing
# Out:
# created missing indicator for : Closed Date
# created missing indicator for : Location Type
# created missing indicator for : Incident Zip
# created missing indicator for : Incident Address
# created missing indicator for : Street Name
# created missing indicator for : Cross Street 1
# created missing indicator for : Cross Street 2
# created missing indicator for : Intersection Street 1
# created missing indicator for : Intersection Street 2
# created missing indicator for : Address Type
# created missing indicator for : City
# created missing indicator for : Landmark
# created missing indicator for : Facility Type
# created missing indicator for : Due Date
# created missing indicator for : Resolution Action Updated Date
# created missing indicator for : X Coordinate (State Plane)
# created missing indicator for : Y Coordinate (State Plane)
# created missing indicator for : School Not Found
# created missing indicator for : School or Citywide Complaint
# ...

# %%
df.shape
# Out:
# (101914, 85)

# %%
#import missingno as msno
#msno.matrix(df.iloc[:, :30])

# %% [markdown]
# Now that you have tried all 3 techniques for detecting missing data, did you find any? Reading through the article, which solution do you think will help you clean the data set and handle the missing data? Try out your solution below!

# %%
# Handle any missing data in your dataframe.
#df with more than 90% missing data
cols_to_drop = []
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    if pct_missing > 0.9:
        cols_to_drop.append(col) 
    
                
df_columns_missing_off = df.drop(cols_to_drop, axis =1, inplace = False)

df_columns_missing_off
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 0         31464015  09/04/2015 12:00:00 AM  09/18/2015 12:00:00 AM  DOHMH
# 1         31464024  09/04/2015 12:00:00 AM  10/28/2015 12:00:00 AM  DOHMH
# 2         31464025  09/04/2015 12:00:00 AM                     NaN  DOHMH
# 3         31464026  09/04/2015 12:00:00 AM  09/14/2015 12:00:00 AM  DOHMH
# 4         31464027  09/04/2015 12:00:00 AM  09/22/2015 12:00:00 AM  DOHMH
# ...            ...                     ...                     ...    ...
# 101909    35494908  02/15/2017 12:00:00 AM  01/31/2017 12:00:00 AM  DOHMH
# 101910    35494944  02/14/2017 12:00:00 AM  02/23/2017 12:00:00 AM  DOHMH
# 101911    35494945  02/14/2017 12:00:00 AM  02/16/2017 12:00:00 AM  DOHMH
# 101912    35494970  02/14/2017 12:00:00 AM  01/17/2017 12:00:00 AM  DOHMH
# 101913    35502334  02/15/2017 04:39:49 AM                     NaN  DOHMH
#
#                                     Agency Name Complaint Type    Descriptor  \
# ...

# %%
cols_to_drop
# Out:
# ['Intersection Street 1',
#  'Intersection Street 2',
#  'Landmark',
#  'Facility Type',
#  'School or Citywide Complaint',
#  'Vehicle Type',
#  'Taxi Company Borough',
#  'Taxi Pick Up Location',
#  'Bridge Highway Name',
#  'Bridge Highway Direction',
#  'Road Ramp',
#  'Bridge Highway Segment',
#  'Garage Lot Name',
#  'Ferry Direction',
#  'Ferry Terminal Name']

# %%
df_columns_missing_off.shape
# Out:
# (101914, 70)

# %%
pd.set_option('max_columns', None)
df
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 0         31464015  09/04/2015 12:00:00 AM  09/18/2015 12:00:00 AM  DOHMH
# 1         31464024  09/04/2015 12:00:00 AM  10/28/2015 12:00:00 AM  DOHMH
# 2         31464025  09/04/2015 12:00:00 AM                     NaN  DOHMH
# 3         31464026  09/04/2015 12:00:00 AM  09/14/2015 12:00:00 AM  DOHMH
# 4         31464027  09/04/2015 12:00:00 AM  09/22/2015 12:00:00 AM  DOHMH
# ...            ...                     ...                     ...    ...
# 101909    35494908  02/15/2017 12:00:00 AM  01/31/2017 12:00:00 AM  DOHMH
# 101910    35494944  02/14/2017 12:00:00 AM  02/23/2017 12:00:00 AM  DOHMH
# 101911    35494945  02/14/2017 12:00:00 AM  02/16/2017 12:00:00 AM  DOHMH
# 101912    35494970  02/14/2017 12:00:00 AM  01/17/2017 12:00:00 AM  DOHMH
# 101913    35502334  02/15/2017 04:39:49 AM                     NaN  DOHMH
#
#                                     Agency Name Complaint Type    Descriptor  \
# ...

# %% [markdown]
# ## Irregular Data
#
# With missing data out of the way, turn your attention to any outliers. Just as we did for missing data, we first need to detect the outliers. The article outlines the top techniques for finding outliers in a dataset.

# %%
# Plot a histogram to see if there are any outliers.
df['Latitude'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
df['Latitude'].describe()
# Out:
# count    101208.000000
# mean         40.739304
# std           0.082224
# min          40.499502
# 25%          40.679740
# 50%          40.725009
# 75%          40.815428
# max          40.912869
# Name: Latitude, dtype: float64

# %%
# Plot a histogram to see if there are any outliers.
df['Borough'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
# Use the describe() method
df['Borough'].describe()
# Out:
# count       101914
# unique           6
# top       BROOKLYN
# freq         34673
# Name: Borough, dtype: object

# %%
# Plot a bar chart
df['Borough'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Which of the three techniques helped you find any outliers? Now that you have found outliers, what will you do to solve the problem?

# %%
# Handle any outliers in your dataframe#will drop the outliers#dftwo = df.drop(['Borough','Unspecified'], axis = 0);
dftwo = df.loc[df['Borough']== 'Unspecified']
dftwo
# Out:
#        Unique Key            Created Date Closed Date Agency  \
# 44059    23291406  05/24/2012 09:04:23 AM         NaN  DOHMH
#
#                                    Agency Name Complaint Type    Descriptor  \
# 44059  Department of Health and Mental Hygiene         Rodent  Rat Sighting
#
#                  Location Type  Incident Zip Incident Address Street Name  \
# 44059  3+ Family Apt. Building           NaN              NaN         NaN
#
#       Cross Street 1 Cross Street 2 Intersection Street 1  \
# 44059            NaN            NaN                   NaN
#
#       Intersection Street 2 Address Type City Landmark  Facility Type  \
# 44059                   NaN      ADDRESS  NaN      NaN            NaN
#
#         Status                Due Date Resolution Action Updated Date  \
# 44059  Pending  06/23/2012 09:04:23 AM         06/15/2012 04:12:13 AM
#
#       Community Board      Borough  X Coordinate (State Plane)  \
# ...

# %% [markdown]
# ## Unnecessary Data
#
# Unnecessary data could be duplicates, irrelevant, or any uninformative data. Dive into each type of unnecessary data to see if there is any in the data set. Make sure to make note of how you would handle each type of unnecessary data.

# %%
# Look for any irrelevant data in the dataframe. How will you handle it?#will drop
df.head()
 df=df[['Unique KEY, CREATED_DATE, LOCATION TYPE, BUROUGH, LATITUDE, LONGITUDE, ZIP']]

# %%
# Look for duplicates. How will you handle any duplicates?
#df_drppduplicates = df.drop('id', axis =1).drop_duplicates() #This is the example from the book???
#df_drppduplicates = df[df.duplicated()]
#df_drppduplicates

# %%
print(df.shape)
df = df.drop_duplicates()
print(df.shape)
# Out:
# (101914, 85)
# (101914, 85)

# %%
print(df.shape)
# Out:
# (101914, 85)

# %%
print(df_drppduplicates.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35756/712766698.py in <module>
# ----> 1 print(df_drppduplicates.shape)
#
# NameError: name 'df_drppduplicates' is not defined

# %%
# Think about what data in the dataframe may be uninformative. Make note here of what situations may render data uninformative and how you would handle it?
#if not informative would drop from frame and analysis

# %% [markdown]
# ## Inconsistent Data
#
# Inconsistent data is anything that messes with your model. This is likely due to inconsistent formatting and can be addressed by re-formatting all values in a column or row.

# %%
# Try to convert all the strings in a column to lower or upper case. 
df['City'] = df['City'].str.upper()
df['Borough'])

# %%
pd.set_option('max_columns', None)
df

# %%
from shapely.geometry import Point
import geopandas
